# %%
import pandas as pd
df_cars=pd.read_csv("../DataSet/shopping_behavior_updated.csv") #? https://archive.ics.uci.edu/ml/machine-learningdatabases/autos/imports-85.data
df_cars1=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data",header=None) 

#? http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.names
df_cars1.to_csv("../DataSet/cars.csv")

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df_cars, title="Pandas Profiling Report")
profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\ACER\Desktop\git projects\IMB_Data_Analyst\sample_excersise\carsdataset.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from ydata_profiling import ProfileReport
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> profile = ProfileReport(df_cars, title="Pandas Profiling Report")
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> profile.to_file("report.html")
#
# ...

# %%
import sweetviz as sv
report = sv.analyze(df_cars)
report.show_html()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\ACER\Desktop\git projects\IMB_Data_Analyst\sample_excersise\carsdataset.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import sweetviz as sv
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> report = sv.analyze(df_cars)
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> report.show_html()
#
# File c:\Users\ACER\Desktop\git projects\IMB_Data_Analyst\IBM_Data_analyst\Lib\site-packages\sweetviz\__init__.py:15
#      12 __license__ = "MIT"
# ...

# %%
import dtale
d = dtale.show(df_cars)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\ACER\Desktop\git projects\IMB_Data_Analyst\sample_excersise\carsdataset.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import dtale
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Desktop/git%20projects/IMB_Data_Analyst/sample_excersise/carsdataset.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> d = dtale.show(df_cars)
#
# ModuleNotFoundError: No module named 'dtale'
